# %% [markdown]
# **取得google drive認證**

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **設定path(本目錄的絕對路徑)**

# %% [markdown]
# **下載 SimpleITK套件**

# %%
path="drive/My Drive/CT"
# !pip install SimpleITK
# Out:
# Collecting SimpleITK
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 76kB/s
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-1.2.4

# %% [markdown]
# **設定3D vgg16**

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten,Dropout
from keras.layers import Conv3D
from keras.layers import MaxPooling3D

input_shape = (128, 128, 64, 1)

model = Sequential([
    Conv3D(64, (2, 2,2), input_shape=input_shape, padding='same',
           activation='relu'),
    Conv3D(64, (2, 2,2), activation='relu', padding='same'),
    MaxPooling3D(pool_size=(2, 2,2), strides=(2, 2,2)),
    Conv3D(128, (2, 2,2), activation='relu', padding='same'),
    Conv3D(128, (2, 2,2), activation='relu', padding='same',),
    MaxPooling3D(pool_size=(2, 2,2), strides=(2, 2,2)),
    Conv3D(256, (2, 2,2), activation='relu', padding='same',),
    Conv3D(256, (2, 2,2), activation='relu', padding='same',),
    Conv3D(256, (2, 2,2), activation='relu', padding='same',),
    MaxPooling3D(pool_size=(2, 2,2), strides=(2, 2,2)),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    MaxPooling3D(pool_size=(2, 2,2), strides=(2, 2,2)),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    Conv3D(512, (2, 2,2), activation='relu', padding='same',),
    MaxPooling3D(pool_size=(2, 2,2), strides=(2, 2,2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dropout(0.25),
    Dense(4, activation='softmax')
])

model.summary()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 128, 128, 64, 64)  576
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 128, 128, 64, 64)  32832
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 64, 64, 32, 64)    0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 64, 64, 32, 128)   65664
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 64, 64, 32, 128)   131200
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 32, 32, 16, 128)   0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 32, 32, 16, 256)   262400
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 32, 32, 16, 256)   524544
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 32, 32, 16, 256)   524544
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 16, 16, 8, 256)    0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 16, 16, 8, 512)    1049088
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 16, 16, 8, 512)    2097664
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 16, 16, 8, 512)    2097664
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 8, 8, 4, 512)      0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 8, 8, 4, 512)      2097664
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 8, 8, 4, 512)      2097664
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 8, 8, 4, 512)      2097664
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 4, 2, 512)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              67112960
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 16388
# =================================================================
# Total params: 96,989,828
# Trainable params: 96,989,828
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **匯入資料**

# %%
import pandas as pd
import SimpleITK as sitk
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import numpy as np

#設定label
label_df=pd.read_csv(path+"label.csv")
labels=label_df['Case']

#onehot encoding 
labels_onehot=np_utils.to_categorical(labels,4)

#宣告一個list存放mask
trainmasks_list=list()

#讀進資料
for m in label_df['mask_name']:
  print("讀進:",m)
  trainmask = sitk.ReadImage(path+"/xVertSeg.v1/Data1/bone_masks/"+str(m)+".mhd")

  trainmasks=sitk.GetArrayFromImage(trainmask)
  trainmasks=trainmasks/trainmasks.max()
  print(trainmasks.min())
  print("trainmasks shape:",trainmasks.shape)
  
  new_trainmasks=np.expand_dims(trainmasks,axis=3)
  print("expand trainmasks shape:",new_trainmasks.shape)

  trainmasks_list.append(new_trainmasks)
  bone_masks_data=np.array(trainmasks_list)
print("bone masks data shape:",bone_masks_data.shape)

#切割 raw data為訓練集和驗證集
x_train,x_test,y_train,y_test=train_test_split(bone_masks_data,labels_onehot,test_size=0.2,random_state=2)
# Out:
# 讀進: bone_mask_L1_1
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_2
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_3
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_4
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_5
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_6
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_7
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_8
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_9
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_10
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_11
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_12
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_13
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_14
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L1_15
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_1
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_2
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_3
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_4
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_5
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_6
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_7
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_8
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_9
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_10
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_11
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_12
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_13
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_14
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L2_15
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_1
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_2
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_3
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_4
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_5
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_6
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_7
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_8
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_9
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_10
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_11
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_12
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_13
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_14
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L3_15
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_1
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_2
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_3
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_4
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_5
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_6
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_7
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_8
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_9
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_10
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_11
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_12
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_13
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_14
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L4_15
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_1
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_2
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_3
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_4
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_5
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_6
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_7
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_8
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_9
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_10
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_11
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_12
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_13
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_14
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# 讀進: bone_mask_L5_15
# 0.0
# trainmasks shape: (128, 128, 64)
# expand trainmasks shape: (128, 128, 64, 1)
# bone masks data shape: (75, 128, 128, 64, 1)

# %% [markdown]
# **開始訓練**

# %%
import numpy as np
from keras.models import *
from keras.layers import *
from keras.optimizers import *

#參數可自行調整
model.compile(optimizer = Adam(lr=1e-5), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=4,epochs=40)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 60 samples, validate on 15 samples
# Epoch 1/40
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60/60 [==============================] - 37s 618ms/step - loss: 1.3860 - acc: 0.3333 - val_loss: 1.3859 - val_acc: 0.2000
# Epoch 2/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.3842 - acc: 0.3833 - val_loss: 1.3839 - val_acc: 0.2000
# Epoch 3/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.3774 - acc: 0.3833 - val_loss: 1.3728 - val_acc: 0.2000
# Epoch 4/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.3355 - acc: 0.3833 - val_loss: 1.3371 - val_acc: 0.2000
# Epoch 5/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.2991 - acc: 0.3833 - val_loss: 1.3102 - val_acc: 0.2000
# Epoch 6/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.2895 - acc: 0.3833 - val_loss: 1.3103 - val_acc: 0.2000
# Epoch 7/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.2822 - acc: 0.4333 - val_loss: 1.2981 - val_acc: 0.4000
# Epoch 8/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.2778 - acc: 0.4000 - val_loss: 1.3184 - val_acc: 0.2000
# Epoch 9/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.2484 - acc: 0.4333 - val_loss: 1.2976 - val_acc: 0.4667
# Epoch 10/40
# 60/60 [==============================] - 18s 293ms/step - loss: 1.2350 - acc: 0.5333 - val_loss: 1.2934 - val_acc: 0.4667
# Epoch 11/40
# 60/60 [==============================] - 18s 293ms/step - loss: 1.2123 - acc: 0.5833 - val_loss: 1.3070 - val_acc: 0.4667
# Epoch 12/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.1904 - acc: 0.5167 - val_loss: 1.3379 - val_acc: 0.4667
# Epoch 13/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.1692 - acc: 0.5167 - val_loss: 1.3416 - val_acc: 0.4667
# Epoch 14/40
# 60/60 [==============================] - 17s 291ms/step - loss: 1.1283 - acc: 0.6000 - val_loss: 1.3385 - val_acc: 0.4667
# Epoch 15/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.0883 - acc: 0.6000 - val_loss: 1.3733 - val_acc: 0.4667
# Epoch 16/40
# 60/60 [==============================] - 17s 292ms/step - loss: 1.0558 - acc: 0.6167 - val_loss: 1.3159 - val_acc: 0.4667
# Epoch 17/40
# 60/60 [==============================] - 17s 291ms/step - loss: 1.0604 - acc: 0.6000 - val_loss: 1.4540 - val_acc: 0.4667
# Epoch 18/40
# 60/60 [==============================] - 17s 291ms/step - loss: 1.0175 - acc: 0.6500 - val_loss: 1.3257 - val_acc: 0.4667
# Epoch 19/40
# 60/60 [==============================] - 18s 293ms/step - loss: 1.0300 - acc: 0.6167 - val_loss: 1.5096 - val_acc: 0.4667
# Epoch 20/40
# 60/60 [==============================] - 17s 291ms/step - loss: 1.0731 - acc: 0.5833 - val_loss: 1.1945 - val_acc: 0.4000
# Epoch 21/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.0025 - acc: 0.6333 - val_loss: 1.3638 - val_acc: 0.4667
# Epoch 22/40
# 60/60 [==============================] - 18s 292ms/step - loss: 1.0005 - acc: 0.6167 - val_loss: 1.2319 - val_acc: 0.4000
# Epoch 23/40
# 60/60 [==============================] - 17s 292ms/step - loss: 0.9816 - acc: 0.6167 - val_loss: 1.3354 - val_acc: 0.4667
# Epoch 24/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.8960 - acc: 0.6667 - val_loss: 1.2586 - val_acc: 0.4667
# Epoch 25/40
# 60/60 [==============================] - 17s 291ms/step - loss: 0.9203 - acc: 0.6833 - val_loss: 1.2860 - val_acc: 0.4667
# Epoch 26/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.9074 - acc: 0.6167 - val_loss: 1.2137 - val_acc: 0.4000
# Epoch 27/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.8706 - acc: 0.6833 - val_loss: 1.1239 - val_acc: 0.4667
# Epoch 28/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.8030 - acc: 0.6333 - val_loss: 1.2271 - val_acc: 0.4667
# Epoch 29/40
# 60/60 [==============================] - 17s 291ms/step - loss: 0.8021 - acc: 0.6333 - val_loss: 1.2295 - val_acc: 0.4667
# Epoch 30/40
# 60/60 [==============================] - 17s 291ms/step - loss: 0.7747 - acc: 0.7000 - val_loss: 1.4845 - val_acc: 0.4000
# Epoch 31/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.8185 - acc: 0.6500 - val_loss: 0.9197 - val_acc: 0.4667
# Epoch 32/40
# 60/60 [==============================] - 17s 292ms/step - loss: 0.7819 - acc: 0.6500 - val_loss: 1.0354 - val_acc: 0.4667
# Epoch 33/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.7311 - acc: 0.7167 - val_loss: 1.2050 - val_acc: 0.4667
# Epoch 34/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.6625 - acc: 0.7500 - val_loss: 1.1867 - val_acc: 0.4667
# Epoch 35/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.6670 - acc: 0.7500 - val_loss: 1.1634 - val_acc: 0.4667
# Epoch 36/40
# 60/60 [==============================] - 18s 292ms/step - loss: 0.6122 - acc: 0.7667 - val_loss: 1.0777 - val_acc: 0.4667
# Epoch 37/40
# 60/60 [==============================] - 18s 293ms/step - loss: 0.6140 - acc: 0.7000 - val_loss: 1.2508 - val_acc: 0.4667
# Epoch 38/40
# 60/60 [==============================] - 17s 291ms/step - loss: 0.6052 - acc: 0.7500 - val_loss: 1.0243 - val_acc: 0.5333
# Epoch 39/40
# 60/60 [==============================] - 17s 292ms/step - loss: 0.5641 - acc: 0.7667 - val_loss: 1.2528 - val_acc: 0.4667
# Epoch 40/40
# 60/60 [==============================] - 17s 291ms/step - loss: 0.5256 - acc: 0.8000 - val_loss: 0.9970 - val_acc: 0.5333
